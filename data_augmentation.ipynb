# %%
import albumentations as A
import cv2
import numpy as np
import matplotlib.pyplot as plt

label= cv2.imread('/data/LEVIR-CD-256/label/train_12_7.png',0)
img= cv2.imread('/data/LEVIR-CD-256/B/train_12_7.png')
plt.imshow(img)

# %%
img= cv2.imread('/data/LEVIR-CD-256/A/train_12_7.png')
plt.imshow(img)

# %%
label= cv2.imread('/data/LEVIR-CD-256/label/train_12_7.png',0)
plt.imshow(label)
